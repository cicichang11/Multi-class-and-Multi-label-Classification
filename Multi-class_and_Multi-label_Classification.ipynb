# %% [markdown]
# <h1>Advanced Analysis of Anuran Calls: Multi-class and Multi-label Classification with Support Vector Machines and K-Means Clustering</h1>

# %% [markdown]
# <h5>This project aims to apply advanced machine learning techniques to the Anuran Calls (MFCCs) Dataset for both classification and clustering challenges. It involves multi-class and multi-label classification using Support Vector Machines (SVMs) and explores the effectiveness of various SVM approaches, including Gaussian kernels, L1-penalized SVMs, and Classifier Chains. The project also addresses class imbalance and evaluates classifiers using metrics like exact match, hamming score, and hamming loss. Additionally, K-Means clustering is used to analyze the dataset, with a focus on determining the majority label in each cluster and calculating the Hamming distance, score, and loss. The project employs a Monte-Carlo Simulation approach to report the average and standard deviation of the results.</h5>

# %% [markdown]
# ## Multi-class and Multi-Label Classification Using Support Vector Machines

# %% [markdown]
# Import packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.metrics import hamming_loss, silhouette_samples, silhouette_score, classification_report, confusion_matrix, f1_score
from sklearn.svm import SVC, LinearSVC
from sklearn.preprocessing import StandardScaler
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Download the Anuran Calls (MFCCs) Data Set

# %%
MFCC_df = pd.read_csv('../data/Anuran Calls (MFCCs)/Frogs_MFCCs.csv')
MFCC_df
# Out:
#       MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0          1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1          1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2          1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3          1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4          1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
# ...        ...       ...       ...       ...       ...       ...       ...
# 7190       1.0 -0.554504 -0.337717  0.035533  0.034511  0.443451  0.093889
# 7191       1.0 -0.517273 -0.370574  0.030673  0.068097  0.402890  0.096628
# 7192       1.0 -0.582557 -0.343237  0.029468  0.064179  0.385596  0.114905
# 7193       1.0 -0.519497 -0.307553 -0.004922  0.072865  0.377131  0.086866
# 7194       1.0 -0.508833 -0.324106  0.062068  0.078211  0.397188  0.094596
#
#       MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  \
# 0    -0.150063 -0.171128  0.124676  ... -0.108351 -0.077623 -0.009568
# 1    -0.222475 -0.207693  0.170883  ... -0.090974 -0.056510 -0.035303
# 2    -0.242234 -0.219153  0.232538  ... -0.050691 -0.023590 -0.066722
# 3    -0.194347 -0.098181  0.270375  ... -0.136009 -0.177037 -0.130498
# 4    -0.265423 -0.172700  0.266434  ... -0.048885 -0.053074 -0.088550
# ...        ...       ...       ...  ...       ...       ...       ...
# 7190 -0.100753  0.037087  0.081075  ...  0.069430  0.071001  0.021591
# 7191 -0.116460  0.063727  0.089034  ...  0.061127  0.068978  0.017745
# 7192 -0.103317  0.070370  0.081317  ...  0.082474  0.077771 -0.009688
# 7193 -0.115799  0.056979  0.089316  ...  0.051796  0.069073  0.017963
# 7194 -0.117672  0.058874  0.076180  ...  0.061455  0.072983 -0.003980
#
#       MFCCs_20  MFCCs_21  MFCCs_22           Family      Genus  \
# 0     0.057684  0.118680  0.014038  Leptodactylidae  Adenomera
# 1     0.020140  0.082263  0.029056  Leptodactylidae  Adenomera
# 2    -0.025083  0.099108  0.077162  Leptodactylidae  Adenomera
# 3    -0.054766 -0.018691  0.023954  Leptodactylidae  Adenomera
# 4    -0.031346  0.108610  0.079244  Leptodactylidae  Adenomera
# ...        ...       ...       ...              ...        ...
# 7190  0.052449 -0.021860 -0.079860          Hylidae     Scinax
# 7191  0.046461 -0.015418 -0.101892          Hylidae     Scinax
# 7192  0.027834 -0.000531 -0.080425          Hylidae     Scinax
# 7193  0.041803 -0.027911 -0.096895          Hylidae     Scinax
# 7194  0.031560 -0.029355 -0.087910          Hylidae     Scinax
#
#              Species  RecordID
# 0     AdenomeraAndre         1
# 1     AdenomeraAndre         1
# 2     AdenomeraAndre         1
# 3     AdenomeraAndre         1
# 4     AdenomeraAndre         1
# ...              ...       ...
# 7190     ScinaxRuber        60
# 7191     ScinaxRuber        60
# 7192     ScinaxRuber        60
# 7193     ScinaxRuber        60
# 7194     ScinaxRuber        60
#
# [7195 rows x 26 columns]

# %% [markdown]
# Choose 70% of the data randomly as the training set.

# %%
# there are 3 target attributes-- Family, Genus, Species 
Family = MFCC_df['Family']
Genus = MFCC_df['Genus']
Species = MFCC_df['Species']

# we need to get 70% the data randomly as the training sets
total_num = len(MFCC_df)
train_index = random.sample(range(total_num), int(total_num * 0.7))

test_index = []
for i in range(total_num):
    if i not in train_index:
        test_index.append(i)

# get train and test stes
MFCC_train = MFCC_df.iloc[train_index, :].reset_index(drop=True)
MFCC_test = MFCC_df.iloc[test_index, :].reset_index(drop=True)

# target features for training
X_train = MFCC_train.iloc[:, :-4]
Family_train = MFCC_train['Family']
Genus_train = MFCC_train['Genus']
Species_train = MFCC_train['Species']

# target features for testing
X_test = MFCC_test.iloc[:, :-4]
Family_test = MFCC_test['Family']
Genus_test = MFCC_test['Genus']
Species_test = MFCC_test['Species']

# %%
MFCC_train.shape
# Out:
# (5036, 26)

# %%
MFCC_test.shape
# Out:
# (2159, 26)

# %% [markdown]
# ### Train a classifier for each label

# %% [markdown]
# #### Research

# %% [markdown]
# <b>Exact Match Ratio</b>: The exact match ratio calculates the percentage of samples where the predicted set of labels exactly matches the true set of labels.
#
#
# <b>Hamming Score/Loss</b>: The hamming loss calculates the fraction of labels that are incorrectly predicted.

# %%
def multiLabelMethods(trueY, predictY):
    # Hamming Loss
    hamming = np.mean(trueY.values != predictY.values)

    # Exact Match Ratio
    exact_match = np.all(trueY.values == predictY.values, axis=1)
    exact_ratio = np.mean(exact_match)

    return np.round(exact_ratio, 4), np.round(hamming, 4),

# %%
def multiLabelEva(title, testX, trueY, classifiers):
    predictY = pd.DataFrame({label: clf.predict(testX) for label, clf in classifiers.items()})
    print(f"Multilabel evaluation of {title}")
    hamming, exact_ratio = multiLabelMethods(trueY, predictY)
    result = {"Hamming Loss": [hamming], "Exact Match Ratio": [exact_ratio]}
    print(pd.DataFrame(data=result))
    return [hamming, exact_ratio]

# %% [markdown]
# #### Train a SVM for each of the labels

# %% [markdown]
# Train a SVM for each of the labels, using Gaussian kernels and one versus all classifiers. Determine the weight of the SVM penalty and the width of the Gaussian Kernel using 10 fold cross validation. You are welcome to try to solve the problem with both standardized and raw attributes and report the results.

# %%
def ParameterSearch(classifier, tuned_params, trainX, trainY, testX, testY, label):
    splitter = StratifiedKFold(n_splits=10, random_state=1234, shuffle=True)
    kwargs = {
        'param_grid': tuned_params,
        'cv': splitter,
        'scoring': 'f1_weighted',
        'verbose': 1
    }

    clf = GridSearchCV(estimator=classifier, **kwargs)
    clf.fit(trainX, trainY)
    
    print(f"Class: {label} (Gaussian SVC without Standardization)")

    # get the results stats
    print("Grid Search Results:\n")
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        mean_rounded = round(mean, 3)
        std_rounded = round(std * 2, 3)
        print(f"Mean Score: {mean_rounded} (±{std_rounded}) for Parameters: {params}")
    
    print("\nThe best parameter setting is:")
    print(clf.best_params_, "\n")
    
    test_pred = clf.predict(testX)
    print(classification_report(testY, test_pred))
    
    return clf

# %%
gaussianSVC_classifiers = {}
tuned_params = {
    'C': np.logspace(0, 3, 5),
    'gamma': np.logspace(-4, 2, 7)
}

# %%
train_data = {
    'train_x': X_train,
    'train_family': Family_train,
    'train_genus': Genus_train,
    'train_species': Species_train
}

test_data = {
    'test_x': X_test,
    'test_family': Family_test,
    'test_genus': Genus_test,
    'test_species': Species_test
}
labels = ['Family', 'Genus', 'Species']

# %% [markdown]
# <b>Gaussian SVC with Raw Attributes</b>

# %%
for label in labels:
    print(label,"(Gaussian SVC without Standardization):")
    result = ParameterSearch(
        SVC(kernel='rbf'),
        tuned_params,
        X_train,
        train_data[f'train_{label.lower()}'],
        X_test,
        test_data[f'test_{label.lower()}'],
        label
    )
    gaussianSVC_classifiers[label] = result
# Out:
# Family (Gaussian SVC without Standardization):
# Fitting 10 folds for each of 35 candidates, totalling 350 fits
# Class: Family (Gaussian SVC without Standardization)
# Grid Search Results:
#
# Mean Score: 0.472 (±0.002) for Parameters: {'C': 1.0, 'gamma': 0.0001}
# Mean Score: 0.485 (±0.013) for Parameters: {'C': 1.0, 'gamma': 0.001}
# Mean Score: 0.866 (±0.035) for Parameters: {'C': 1.0, 'gamma': 0.01}
# Mean Score: 0.935 (±0.017) for Parameters: {'C': 1.0, 'gamma': 0.1}
# Mean Score: 0.986 (±0.007) for Parameters: {'C': 1.0, 'gamma': 1.0}
# Mean Score: 0.985 (±0.015) for Parameters: {'C': 1.0, 'gamma': 10.0}
# Mean Score: 0.761 (±0.048) for Parameters: {'C': 1.0, 'gamma': 100.0}
# Mean Score: 0.472 (±0.002) for Parameters: {'C': 5.623413251903491, 'gamma': 0.0001}
# Mean Score: 0.791 (±0.024) for Parameters: {'C': 5.623413251903491, 'gamma': 0.001}
# Mean Score: 0.92 (±0.017) for Parameters: {'C': 5.623413251903491, 'gamma': 0.01}
# Mean Score: 0.958 (±0.008) for Parameters: {'C': 5.623413251903491, 'gamma': 0.1}
# Mean Score: 0.991 (±0.007) for Parameters: {'C': 5.623413251903491, 'gamma': 1.0}
# Mean Score: 0.986 (±0.012) for Parameters: {'C': 5.623413251903491, 'gamma': 10.0}
# Mean Score: 0.776 (±0.045) for Parameters: {'C': 5.623413251903491, 'gamma': 100.0}
# Mean Score: 0.77 (±0.039) for Parameters: {'C': 31.622776601683793, 'gamma': 0.0001}
# Mean Score: 0.911 (±0.017) for Parameters: {'C': 31.622776601683793, 'gamma': 0.001}
# Mean Score: 0.938 (±0.016) for Parameters: {'C': 31.622776601683793, 'gamma': 0.01}
# Mean Score: 0.978 (±0.01) for Parameters: {'C': 31.622776601683793, 'gamma': 0.1}
# Mean Score: 0.994 (±0.005) for Parameters: {'C': 31.622776601683793, 'gamma': 1.0}
# Mean Score: 0.986 (±0.012) for Parameters: {'C': 31.622776601683793, 'gamma': 10.0}
# Mean Score: 0.776 (±0.045) for Parameters: {'C': 31.622776601683793, 'gamma': 100.0}
# Mean Score: 0.899 (±0.026) for Parameters: {'C': 177.82794100389228, 'gamma': 0.0001}
# Mean Score: 0.932 (±0.019) for Parameters: {'C': 177.82794100389228, 'gamma': 0.001}
# Mean Score: 0.947 (±0.016) for Parameters: {'C': 177.82794100389228, 'gamma': 0.01}
# Mean Score: 0.986 (±0.008) for Parameters: {'C': 177.82794100389228, 'gamma': 0.1}
# Mean Score: 0.994 (±0.005) for Parameters: {'C': 177.82794100389228, 'gamma': 1.0}
# Mean Score: 0.986 (±0.012) for Parameters: {'C': 177.82794100389228, 'gamma': 10.0}
# Mean Score: 0.776 (±0.045) for Parameters: {'C': 177.82794100389228, 'gamma': 100.0}
# Mean Score: 0.923 (±0.02) for Parameters: {'C': 1000.0, 'gamma': 0.0001}
# Mean Score: 0.938 (±0.014) for Parameters: {'C': 1000.0, 'gamma': 0.001}
# Mean Score: 0.971 (±0.01) for Parameters: {'C': 1000.0, 'gamma': 0.01}
# Mean Score: 0.989 (±0.008) for Parameters: {'C': 1000.0, 'gamma': 0.1}
# Mean Score: 0.994 (±0.005) for Parameters: {'C': 1000.0, 'gamma': 1.0}
# Mean Score: 0.986 (±0.012) for Parameters: {'C': 1000.0, 'gamma': 10.0}
# Mean Score: 0.776 (±0.045) for Parameters: {'C': 1000.0, 'gamma': 100.0}
#
# The best parameter setting is:
# {'C': 177.82794100389228, 'gamma': 1.0}
#
#                  precision    recall  f1-score   support
#
#       Bufonidae       0.91      0.91      0.91        23
#   Dendrobatidae       0.99      0.99      0.99       161
#         Hylidae       0.99      0.99      0.99       666
# Leptodactylidae       0.99      0.99      0.99      1309
#
#        accuracy                           0.99      2159
#       macro avg       0.97      0.97      0.97      2159
#    weighted avg       0.99      0.99      0.99      2159
#
# Genus (Gaussian SVC without Standardization):
# Fitting 10 folds for each of 35 candidates, totalling 350 fits
# Class: Genus (Gaussian SVC without Standardization)
# Grid Search Results:
#
# Mean Score: 0.427 (±0.002) for Parameters: {'C': 1.0, 'gamma': 0.0001}
# Mean Score: 0.427 (±0.002) for Parameters: {'C': 1.0, 'gamma': 0.001}
# Mean Score: 0.744 (±0.029) for Parameters: {'C': 1.0, 'gamma': 0.01}
# Mean Score: 0.919 (±0.022) for Parameters: {'C': 1.0, 'gamma': 0.1}
# Mean Score: 0.984 (±0.014) for Parameters: {'C': 1.0, 'gamma': 1.0}
# Mean Score: 0.979 (±0.015) for Parameters: {'C': 1.0, 'gamma': 10.0}
# Mean Score: 0.702 (±0.033) for Parameters: {'C': 1.0, 'gamma': 100.0}
# Mean Score: 0.427 (±0.002) for Parameters: {'C': 5.623413251903491, 'gamma': 0.0001}
# Mean Score: 0.658 (±0.026) for Parameters: {'C': 5.623413251903491, 'gamma': 0.001}
# Mean Score: 0.9 (±0.025) for Parameters: {'C': 5.623413251903491, 'gamma': 0.01}
# Mean Score: 0.965 (±0.02) for Parameters: {'C': 5.623413251903491, 'gamma': 0.1}
# Mean Score: 0.99 (±0.009) for Parameters: {'C': 5.623413251903491, 'gamma': 1.0}
# Mean Score: 0.98 (±0.015) for Parameters: {'C': 5.623413251903491, 'gamma': 10.0}
# Mean Score: 0.724 (±0.037) for Parameters: {'C': 5.623413251903491, 'gamma': 100.0}
# Mean Score: 0.57 (±0.029) for Parameters: {'C': 31.622776601683793, 'gamma': 0.0001}
# Mean Score: 0.859 (±0.022) for Parameters: {'C': 31.622776601683793, 'gamma': 0.001}
# Mean Score: 0.943 (±0.026) for Parameters: {'C': 31.622776601683793, 'gamma': 0.01}
# Mean Score: 0.982 (±0.015) for Parameters: {'C': 31.622776601683793, 'gamma': 0.1}
# Mean Score: 0.989 (±0.012) for Parameters: {'C': 31.622776601683793, 'gamma': 1.0}
# Mean Score: 0.98 (±0.015) for Parameters: {'C': 31.622776601683793, 'gamma': 10.0}
# Mean Score: 0.724 (±0.037) for Parameters: {'C': 31.622776601683793, 'gamma': 100.0}
# Mean Score: 0.839 (±0.017) for Parameters: {'C': 177.82794100389228, 'gamma': 0.0001}
# Mean Score: 0.929 (±0.024) for Parameters: {'C': 177.82794100389228, 'gamma': 0.001}
# Mean Score: 0.97 (±0.016) for Parameters: {'C': 177.82794100389228, 'gamma': 0.01}
# Mean Score: 0.986 (±0.007) for Parameters: {'C': 177.82794100389228, 'gamma': 0.1}
# Mean Score: 0.989 (±0.014) for Parameters: {'C': 177.82794100389228, 'gamma': 1.0}
# Mean Score: 0.98 (±0.015) for Parameters: {'C': 177.82794100389228, 'gamma': 10.0}
# Mean Score: 0.724 (±0.037) for Parameters: {'C': 177.82794100389228, 'gamma': 100.0}
# Mean Score: 0.917 (±0.023) for Parameters: {'C': 1000.0, 'gamma': 0.0001}
# Mean Score: 0.956 (±0.015) for Parameters: {'C': 1000.0, 'gamma': 0.001}
# Mean Score: 0.975 (±0.015) for Parameters: {'C': 1000.0, 'gamma': 0.01}
# Mean Score: 0.988 (±0.01) for Parameters: {'C': 1000.0, 'gamma': 0.1}
# Mean Score: 0.989 (±0.014) for Parameters: {'C': 1000.0, 'gamma': 1.0}
# Mean Score: 0.98 (±0.015) for Parameters: {'C': 1000.0, 'gamma': 10.0}
# Mean Score: 0.724 (±0.037) for Parameters: {'C': 1000.0, 'gamma': 100.0}
#
# The best parameter setting is:
# {'C': 5.623413251903491, 'gamma': 1.0}
#
#                precision    recall  f1-score   support
#
#     Adenomera       0.99      0.99      0.99      1226
#      Ameerega       0.99      1.00      1.00       161
# Dendropsophus       0.96      0.88      0.92        78
#     Hypsiboas       0.99      1.00      0.99       514
# Leptodactylus       0.99      0.99      0.99        83
# Osteocephalus       0.94      0.94      0.94        35
#      Rhinella       1.00      0.91      0.95        23
#        Scinax       0.97      1.00      0.99        39
#
#      accuracy                           0.99      2159
#     macro avg       0.98      0.96      0.97      2159
#  weighted avg       0.99      0.99      0.99      2159
#
# Species (Gaussian SVC without Standardization):
# Fitting 10 folds for each of 35 candidates, totalling 350 fits
# Class: Species (Gaussian SVC without Standardization)
# Grid Search Results:
#
# Mean Score: 0.321 (±0.001) for Parameters: {'C': 1.0, 'gamma': 0.0001}
# Mean Score: 0.37 (±0.015) for Parameters: {'C': 1.0, 'gamma': 0.001}
# Mean Score: 0.79 (±0.018) for Parameters: {'C': 1.0, 'gamma': 0.01}
# Mean Score: 0.934 (±0.021) for Parameters: {'C': 1.0, 'gamma': 0.1}
# Mean Score: 0.985 (±0.009) for Parameters: {'C': 1.0, 'gamma': 1.0}
# Mean Score: 0.977 (±0.015) for Parameters: {'C': 1.0, 'gamma': 10.0}
# Mean Score: 0.614 (±0.026) for Parameters: {'C': 1.0, 'gamma': 100.0}
# Mean Score: 0.321 (±0.001) for Parameters: {'C': 5.623413251903491, 'gamma': 0.0001}
# Mean Score: 0.753 (±0.019) for Parameters: {'C': 5.623413251903491, 'gamma': 0.001}
# Mean Score: 0.911 (±0.022) for Parameters: {'C': 5.623413251903491, 'gamma': 0.01}
# Mean Score: 0.97 (±0.01) for Parameters: {'C': 5.623413251903491, 'gamma': 0.1}
# Mean Score: 0.99 (±0.006) for Parameters: {'C': 5.623413251903491, 'gamma': 1.0}
# Mean Score: 0.977 (±0.014) for Parameters: {'C': 5.623413251903491, 'gamma': 10.0}
# Mean Score: 0.642 (±0.022) for Parameters: {'C': 5.623413251903491, 'gamma': 100.0}
# Mean Score: 0.659 (±0.017) for Parameters: {'C': 31.622776601683793, 'gamma': 0.0001}
# Mean Score: 0.891 (±0.023) for Parameters: {'C': 31.622776601683793, 'gamma': 0.001}
# Mean Score: 0.964 (±0.011) for Parameters: {'C': 31.622776601683793, 'gamma': 0.01}
# Mean Score: 0.984 (±0.013) for Parameters: {'C': 31.622776601683793, 'gamma': 0.1}
# Mean Score: 0.99 (±0.006) for Parameters: {'C': 31.622776601683793, 'gamma': 1.0}
# Mean Score: 0.977 (±0.014) for Parameters: {'C': 31.622776601683793, 'gamma': 10.0}
# Mean Score: 0.642 (±0.022) for Parameters: {'C': 31.622776601683793, 'gamma': 100.0}
# Mean Score: 0.853 (±0.016) for Parameters: {'C': 177.82794100389228, 'gamma': 0.0001}
# Mean Score: 0.947 (±0.014) for Parameters: {'C': 177.82794100389228, 'gamma': 0.001}
# Mean Score: 0.978 (±0.013) for Parameters: {'C': 177.82794100389228, 'gamma': 0.01}
# Mean Score: 0.988 (±0.008) for Parameters: {'C': 177.82794100389228, 'gamma': 0.1}
# Mean Score: 0.99 (±0.006) for Parameters: {'C': 177.82794100389228, 'gamma': 1.0}
# Mean Score: 0.977 (±0.014) for Parameters: {'C': 177.82794100389228, 'gamma': 10.0}
# Mean Score: 0.642 (±0.022) for Parameters: {'C': 177.82794100389228, 'gamma': 100.0}
# Mean Score: 0.933 (±0.023) for Parameters: {'C': 1000.0, 'gamma': 0.0001}
# Mean Score: 0.972 (±0.013) for Parameters: {'C': 1000.0, 'gamma': 0.001}
# Mean Score: 0.982 (±0.012) for Parameters: {'C': 1000.0, 'gamma': 0.01}
# Mean Score: 0.989 (±0.008) for Parameters: {'C': 1000.0, 'gamma': 0.1}
# Mean Score: 0.99 (±0.006) for Parameters: {'C': 1000.0, 'gamma': 1.0}
# Mean Score: 0.977 (±0.014) for Parameters: {'C': 1000.0, 'gamma': 10.0}
# Mean Score: 0.642 (±0.022) for Parameters: {'C': 1000.0, 'gamma': 100.0}
#
# The best parameter setting is:
# {'C': 5.623413251903491, 'gamma': 1.0}
#
#                         precision    recall  f1-score   support
#
#         AdenomeraAndre       0.98      0.97      0.97       209
# AdenomeraHylaedactylus       1.00      1.00      1.00      1017
#     Ameeregatrivittata       0.99      1.00      1.00       161
#             HylaMinuta       0.97      0.91      0.94        78
#   HypsiboasCinerascens       0.97      1.00      0.98       155
#      HypsiboasCordobae       0.99      1.00      0.99       359
#    LeptodactylusFuscus       0.99      0.99      0.99        83
#  OsteocephalusOophagus       0.94      0.94      0.94        35
#      Rhinellagranulosa       1.00      0.91      0.95        23
#            ScinaxRuber       1.00      0.97      0.99        39
#
#               accuracy                           0.99      2159
#              macro avg       0.98      0.97      0.98      2159
#           weighted avg       0.99      0.99      0.99      2159

# %%
multiLabelEva("Gaussian SVC with Raw Attributes", X_test, MFCC_test.iloc[:, -4:-1], gaussianSVC_classifiers)
# Out:
# Multilabel evaluation of Gaussian SVC with Raw Attributes
#    Hamming Loss  Exact Match Ratio
# 0        0.9856               0.01
# [0.9856, 0.01]

# %% [markdown]
# <b>Gaussian SVC with Standardized Attributes</b>

# %%
# standardize the attributes
StdScaler = StandardScaler()
X_train_STD = StdScaler.fit_transform(X_train)
X_test_STD = StdScaler.fit_transform(X_test)

# %%
for label in labels:
    # print(label,"(Gaussian SVC without Standardization):")
    result = ParameterSearch(
        SVC(kernel='rbf'),
        tuned_params,
        X_train_STD,
        train_data[f'train_{label.lower()}'],
        X_test_STD,
        test_data[f'test_{label.lower()}'],
        label
    )
    gaussianSVC_classifiers[label] = result
# Out:
# Fitting 10 folds for each of 35 candidates, totalling 350 fits
# Class: Family (Gaussian SVC without Standardization)
# Grid Search Results:
#
# Mean Score: 0.801 (±0.02) for Parameters: {'C': 1.0, 'gamma': 0.0001}
# Mean Score: 0.928 (±0.017) for Parameters: {'C': 1.0, 'gamma': 0.001}
# Mean Score: 0.965 (±0.01) for Parameters: {'C': 1.0, 'gamma': 0.01}
# Mean Score: 0.988 (±0.012) for Parameters: {'C': 1.0, 'gamma': 0.1}
# Mean Score: 0.898 (±0.021) for Parameters: {'C': 1.0, 'gamma': 1.0}
# Mean Score: 0.55 (±0.03) for Parameters: {'C': 1.0, 'gamma': 10.0}
# Mean Score: 0.475 (±0.006) for Parameters: {'C': 1.0, 'gamma': 100.0}
# Mean Score: 0.916 (±0.019) for Parameters: {'C': 5.623413251903491, 'gamma': 0.0001}
# Mean Score: 0.942 (±0.017) for Parameters: {'C': 5.623413251903491, 'gamma': 0.001}
# Mean Score: 0.985 (±0.01) for Parameters: {'C': 5.623413251903491, 'gamma': 0.01}
# Mean Score: 0.991 (±0.01) for Parameters: {'C': 5.623413251903491, 'gamma': 0.1}
# Mean Score: 0.902 (±0.02) for Parameters: {'C': 5.623413251903491, 'gamma': 1.0}
# Mean Score: 0.567 (±0.033) for Parameters: {'C': 5.623413251903491, 'gamma': 10.0}
# Mean Score: 0.475 (±0.005) for Parameters: {'C': 5.623413251903491, 'gamma': 100.0}
# Mean Score: 0.935 (±0.015) for Parameters: {'C': 31.622776601683793, 'gamma': 0.0001}
# Mean Score: 0.955 (±0.011) for Parameters: {'C': 31.622776601683793, 'gamma': 0.001}
# Mean Score: 0.99 (±0.008) for Parameters: {'C': 31.622776601683793, 'gamma': 0.01}
# Mean Score: 0.991 (±0.009) for Parameters: {'C': 31.622776601683793, 'gamma': 0.1}
# Mean Score: 0.902 (±0.02) for Parameters: {'C': 31.622776601683793, 'gamma': 1.0}
# Mean Score: 0.567 (±0.033) for Parameters: {'C': 31.622776601683793, 'gamma': 10.0}
# Mean Score: 0.475 (±0.005) for Parameters: {'C': 31.622776601683793, 'gamma': 100.0}
# Mean Score: 0.94 (±0.016) for Parameters: {'C': 177.82794100389228, 'gamma': 0.0001}
# Mean Score: 0.978 (±0.009) for Parameters: {'C': 177.82794100389228, 'gamma': 0.001}
# Mean Score: 0.991 (±0.007) for Parameters: {'C': 177.82794100389228, 'gamma': 0.01}
# Mean Score: 0.991 (±0.009) for Parameters: {'C': 177.82794100389228, 'gamma': 0.1}
# Mean Score: 0.902 (±0.02) for Parameters: {'C': 177.82794100389228, 'gamma': 1.0}
# Mean Score: 0.567 (±0.033) for Parameters: {'C': 177.82794100389228, 'gamma': 10.0}
# Mean Score: 0.475 (±0.005) for Parameters: {'C': 177.82794100389228, 'gamma': 100.0}
# Mean Score: 0.953 (±0.012) for Parameters: {'C': 1000.0, 'gamma': 0.0001}
# Mean Score: 0.985 (±0.011) for Parameters: {'C': 1000.0, 'gamma': 0.001}
# Mean Score: 0.991 (±0.01) for Parameters: {'C': 1000.0, 'gamma': 0.01}
# Mean Score: 0.991 (±0.009) for Parameters: {'C': 1000.0, 'gamma': 0.1}
# Mean Score: 0.902 (±0.02) for Parameters: {'C': 1000.0, 'gamma': 1.0}
# Mean Score: 0.567 (±0.033) for Parameters: {'C': 1000.0, 'gamma': 10.0}
# Mean Score: 0.475 (±0.005) for Parameters: {'C': 1000.0, 'gamma': 100.0}
#
# The best parameter setting is:
# {'C': 1000.0, 'gamma': 0.01}
#
#                  precision    recall  f1-score   support
#
#       Bufonidae       0.91      0.87      0.89        23
#   Dendrobatidae       0.98      0.99      0.98       161
#         Hylidae       0.99      0.98      0.99       666
# Leptodactylidae       0.99      0.99      0.99      1309
#
#        accuracy                           0.99      2159
#       macro avg       0.97      0.96      0.96      2159
#    weighted avg       0.99      0.99      0.99      2159
#
# Fitting 10 folds for each of 35 candidates, totalling 350 fits
# Class: Genus (Gaussian SVC without Standardization)
# Grid Search Results:
#
# Mean Score: 0.691 (±0.013) for Parameters: {'C': 1.0, 'gamma': 0.0001}
# Mean Score: 0.886 (±0.027) for Parameters: {'C': 1.0, 'gamma': 0.001}
# Mean Score: 0.969 (±0.02) for Parameters: {'C': 1.0, 'gamma': 0.01}
# Mean Score: 0.986 (±0.01) for Parameters: {'C': 1.0, 'gamma': 0.1}
# Mean Score: 0.833 (±0.028) for Parameters: {'C': 1.0, 'gamma': 1.0}
# Mean Score: 0.493 (±0.019) for Parameters: {'C': 1.0, 'gamma': 10.0}
# Mean Score: 0.429 (±0.005) for Parameters: {'C': 1.0, 'gamma': 100.0}
# Mean Score: 0.86 (±0.025) for Parameters: {'C': 5.623413251903491, 'gamma': 0.0001}
# Mean Score: 0.941 (±0.023) for Parameters: {'C': 5.623413251903491, 'gamma': 0.001}
# Mean Score: 0.987 (±0.012) for Parameters: {'C': 5.623413251903491, 'gamma': 0.01}
# Mean Score: 0.987 (±0.012) for Parameters: {'C': 5.623413251903491, 'gamma': 0.1}
# Mean Score: 0.846 (±0.026) for Parameters: {'C': 5.623413251903491, 'gamma': 1.0}
# Mean Score: 0.506 (±0.021) for Parameters: {'C': 5.623413251903491, 'gamma': 10.0}
# Mean Score: 0.43 (±0.006) for Parameters: {'C': 5.623413251903491, 'gamma': 100.0}
# Mean Score: 0.925 (±0.028) for Parameters: {'C': 31.622776601683793, 'gamma': 0.0001}
# Mean Score: 0.973 (±0.016) for Parameters: {'C': 31.622776601683793, 'gamma': 0.001}
# Mean Score: 0.989 (±0.011) for Parameters: {'C': 31.622776601683793, 'gamma': 0.01}
# Mean Score: 0.987 (±0.011) for Parameters: {'C': 31.622776601683793, 'gamma': 0.1}
# Mean Score: 0.846 (±0.026) for Parameters: {'C': 31.622776601683793, 'gamma': 1.0}
# Mean Score: 0.506 (±0.021) for Parameters: {'C': 31.622776601683793, 'gamma': 10.0}
# Mean Score: 0.43 (±0.006) for Parameters: {'C': 31.622776601683793, 'gamma': 100.0}
# Mean Score: 0.965 (±0.017) for Parameters: {'C': 177.82794100389228, 'gamma': 0.0001}
# Mean Score: 0.98 (±0.015) for Parameters: {'C': 177.82794100389228, 'gamma': 0.001}
# Mean Score: 0.989 (±0.012) for Parameters: {'C': 177.82794100389228, 'gamma': 0.01}
# Mean Score: 0.987 (±0.011) for Parameters: {'C': 177.82794100389228, 'gamma': 0.1}
# Mean Score: 0.846 (±0.026) for Parameters: {'C': 177.82794100389228, 'gamma': 1.0}
# Mean Score: 0.506 (±0.021) for Parameters: {'C': 177.82794100389228, 'gamma': 10.0}
# Mean Score: 0.43 (±0.006) for Parameters: {'C': 177.82794100389228, 'gamma': 100.0}
# Mean Score: 0.971 (±0.016) for Parameters: {'C': 1000.0, 'gamma': 0.0001}
# Mean Score: 0.986 (±0.011) for Parameters: {'C': 1000.0, 'gamma': 0.001}
# Mean Score: 0.989 (±0.012) for Parameters: {'C': 1000.0, 'gamma': 0.01}
# Mean Score: 0.987 (±0.011) for Parameters: {'C': 1000.0, 'gamma': 0.1}
# Mean Score: 0.846 (±0.026) for Parameters: {'C': 1000.0, 'gamma': 1.0}
# Mean Score: 0.506 (±0.021) for Parameters: {'C': 1000.0, 'gamma': 10.0}
# Mean Score: 0.43 (±0.006) for Parameters: {'C': 1000.0, 'gamma': 100.0}
#
# The best parameter setting is:
# {'C': 1000.0, 'gamma': 0.01}
#
#                precision    recall  f1-score   support
#
#     Adenomera       1.00      0.99      0.99      1226
#      Ameerega       0.98      1.00      0.99       161
# Dendropsophus       0.96      0.94      0.95        78
#     Hypsiboas       0.99      1.00      0.99       514
# Leptodactylus       0.99      0.98      0.98        83
# Osteocephalus       0.94      0.89      0.91        35
#      Rhinella       1.00      0.96      0.98        23
#        Scinax       0.97      0.97      0.97        39
#
#      accuracy                           0.99      2159
#     macro avg       0.98      0.97      0.97      2159
#  weighted avg       0.99      0.99      0.99      2159
#
# Fitting 10 folds for each of 35 candidates, totalling 350 fits
# Class: Species (Gaussian SVC without Standardization)
# Grid Search Results:
#
# Mean Score: 0.692 (±0.009) for Parameters: {'C': 1.0, 'gamma': 0.0001}
# Mean Score: 0.905 (±0.027) for Parameters: {'C': 1.0, 'gamma': 0.001}
# Mean Score: 0.973 (±0.006) for Parameters: {'C': 1.0, 'gamma': 0.01}
# Mean Score: 0.983 (±0.011) for Parameters: {'C': 1.0, 'gamma': 0.1}
# Mean Score: 0.81 (±0.024) for Parameters: {'C': 1.0, 'gamma': 1.0}
# Mean Score: 0.38 (±0.015) for Parameters: {'C': 1.0, 'gamma': 10.0}
# Mean Score: 0.323 (±0.005) for Parameters: {'C': 1.0, 'gamma': 100.0}
# Mean Score: 0.868 (±0.016) for Parameters: {'C': 5.623413251903491, 'gamma': 0.0001}
# Mean Score: 0.964 (±0.009) for Parameters: {'C': 5.623413251903491, 'gamma': 0.001}
# Mean Score: 0.987 (±0.009) for Parameters: {'C': 5.623413251903491, 'gamma': 0.01}
# Mean Score: 0.985 (±0.009) for Parameters: {'C': 5.623413251903491, 'gamma': 0.1}
# Mean Score: 0.826 (±0.021) for Parameters: {'C': 5.623413251903491, 'gamma': 1.0}
# Mean Score: 0.392 (±0.021) for Parameters: {'C': 5.623413251903491, 'gamma': 10.0}
# Mean Score: 0.324 (±0.006) for Parameters: {'C': 5.623413251903491, 'gamma': 100.0}
# Mean Score: 0.944 (±0.015) for Parameters: {'C': 31.622776601683793, 'gamma': 0.0001}
# Mean Score: 0.977 (±0.013) for Parameters: {'C': 31.622776601683793, 'gamma': 0.001}
# Mean Score: 0.989 (±0.006) for Parameters: {'C': 31.622776601683793, 'gamma': 0.01}
# Mean Score: 0.985 (±0.008) for Parameters: {'C': 31.622776601683793, 'gamma': 0.1}
# Mean Score: 0.826 (±0.021) for Parameters: {'C': 31.622776601683793, 'gamma': 1.0}
# Mean Score: 0.392 (±0.021) for Parameters: {'C': 31.622776601683793, 'gamma': 10.0}
# Mean Score: 0.324 (±0.006) for Parameters: {'C': 31.622776601683793, 'gamma': 100.0}
# Mean Score: 0.971 (±0.011) for Parameters: {'C': 177.82794100389228, 'gamma': 0.0001}
# Mean Score: 0.984 (±0.009) for Parameters: {'C': 177.82794100389228, 'gamma': 0.001}
# Mean Score: 0.988 (±0.007) for Parameters: {'C': 177.82794100389228, 'gamma': 0.01}
# Mean Score: 0.985 (±0.008) for Parameters: {'C': 177.82794100389228, 'gamma': 0.1}
# Mean Score: 0.826 (±0.021) for Parameters: {'C': 177.82794100389228, 'gamma': 1.0}
# Mean Score: 0.392 (±0.021) for Parameters: {'C': 177.82794100389228, 'gamma': 10.0}
# Mean Score: 0.324 (±0.006) for Parameters: {'C': 177.82794100389228, 'gamma': 100.0}
# Mean Score: 0.98 (±0.013) for Parameters: {'C': 1000.0, 'gamma': 0.0001}
# Mean Score: 0.986 (±0.009) for Parameters: {'C': 1000.0, 'gamma': 0.001}
# Mean Score: 0.988 (±0.007) for Parameters: {'C': 1000.0, 'gamma': 0.01}
# Mean Score: 0.985 (±0.008) for Parameters: {'C': 1000.0, 'gamma': 0.1}
# Mean Score: 0.826 (±0.021) for Parameters: {'C': 1000.0, 'gamma': 1.0}
# Mean Score: 0.392 (±0.021) for Parameters: {'C': 1000.0, 'gamma': 10.0}
# Mean Score: 0.324 (±0.006) for Parameters: {'C': 1000.0, 'gamma': 100.0}
#
# The best parameter setting is:
# {'C': 31.622776601683793, 'gamma': 0.01}
#
#                         precision    recall  f1-score   support
#
#         AdenomeraAndre       0.98      0.96      0.97       209
# AdenomeraHylaedactylus       1.00      1.00      1.00      1017
#     Ameeregatrivittata       0.98      0.99      0.98       161
#             HylaMinuta       0.95      0.92      0.94        78
#   HypsiboasCinerascens       0.97      1.00      0.98       155
#      HypsiboasCordobae       0.99      0.99      0.99       359
#    LeptodactylusFuscus       0.98      0.98      0.98        83
#  OsteocephalusOophagus       0.91      0.91      0.91        35
#      Rhinellagranulosa       1.00      0.91      0.95        23
#            ScinaxRuber       1.00      0.97      0.99        39
#
#               accuracy                           0.99      2159
#              macro avg       0.97      0.96      0.97      2159
#           weighted avg       0.99      0.99      0.99      2159

# %%
multiLabelEva("Gaussian SVC with Standardized Attributes", X_test_STD, MFCC_test.iloc[:, -4:-1], gaussianSVC_classifiers)
# Out:
# Multilabel evaluation of Gaussian SVC with Standardized Attributes
#    Hamming Loss  Exact Match Ratio
# 0        0.9819             0.0117
# [0.9819, 0.0117]

# %% [markdown]
# <b>L1-penalized SVMs with Standardized Attributes</b>

# %%
L1_penalized_std_attri= {}
tuned_params = {
    'C': np.logspace(0, 3, 5)
}
for label in labels:
    # print(label,"(Gaussian SVC without Standardization):")
    result = ParameterSearch(
        LinearSVC(penalty='l1', dual=False),
        tuned_params,
        X_train_STD,
        train_data[f'train_{label.lower()}'],
        X_test_STD,
        test_data[f'test_{label.lower()}'],
        label
    )
    L1_penalized_std_attri[label] = result
# Out:
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# Class: Family (Gaussian SVC without Standardization)
# Grid Search Results:
#
# Mean Score: 0.93 (±0.018) for Parameters: {'C': 1.0}
# Mean Score: 0.93 (±0.018) for Parameters: {'C': 5.623413251903491}
# Mean Score: 0.93 (±0.018) for Parameters: {'C': 31.622776601683793}
# Mean Score: 0.93 (±0.018) for Parameters: {'C': 177.82794100389228}
# Mean Score: 0.93 (±0.018) for Parameters: {'C': 1000.0}
#
# The best parameter setting is:
# {'C': 5.623413251903491}
#
#                  precision    recall  f1-score   support
#
#       Bufonidae       0.00      0.00      0.00        23
#   Dendrobatidae       0.90      0.92      0.91       161
#         Hylidae       0.92      0.93      0.92       666
# Leptodactylidae       0.96      0.97      0.97      1309
#
#        accuracy                           0.94      2159
#       macro avg       0.70      0.70      0.70      2159
#    weighted avg       0.93      0.94      0.94      2159
#
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# Class: Genus (Gaussian SVC without Standardization)
# Grid Search Results:
#
# Mean Score: 0.943 (±0.029) for Parameters: {'C': 1.0}
# Mean Score: 0.946 (±0.028) for Parameters: {'C': 5.623413251903491}
# Mean Score: 0.946 (±0.029) for Parameters: {'C': 31.622776601683793}
# Mean Score: 0.946 (±0.029) for Parameters: {'C': 177.82794100389228}
# Mean Score: 0.946 (±0.029) for Parameters: {'C': 1000.0}
#
# The best parameter setting is:
# {'C': 5.623413251903491}
#
#                precision    recall  f1-score   support
#
#     Adenomera       0.96      0.98      0.97      1226
#      Ameerega       0.92      0.92      0.92       161
# Dendropsophus       0.79      0.72      0.75        78
#     Hypsiboas       0.95      0.97      0.96       514
# Leptodactylus       0.95      0.89      0.92        83
# Osteocephalus       0.85      0.49      0.62        35
#      Rhinella       0.75      0.26      0.39        23
#        Scinax       0.93      0.97      0.95        39
#
#      accuracy                           0.95      2159
#     macro avg       0.89      0.78      0.81      2159
#  weighted avg       0.94      0.95      0.94      2159
#
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# Class: Species (Gaussian SVC without Standardization)
# Grid Search Results:
#
# Mean Score: 0.956 (±0.008) for Parameters: {'C': 1.0}
# Mean Score: 0.957 (±0.01) for Parameters: {'C': 5.623413251903491}
# Mean Score: 0.957 (±0.01) for Parameters: {'C': 31.622776601683793}
# Mean Score: 0.957 (±0.01) for Parameters: {'C': 177.82794100389228}
# Mean Score: 0.957 (±0.01) for Parameters: {'C': 1000.0}
#
# The best parameter setting is:
# {'C': 31.622776601683793}
#
#                         precision    recall  f1-score   support
#
#         AdenomeraAndre       0.91      0.92      0.91       209
# AdenomeraHylaedactylus       0.99      1.00      0.99      1017
#     Ameeregatrivittata       0.92      0.91      0.92       161
#             HylaMinuta       0.80      0.77      0.78        78
#   HypsiboasCinerascens       0.94      0.95      0.95       155
#      HypsiboasCordobae       0.95      0.97      0.96       359
#    LeptodactylusFuscus       0.97      0.90      0.94        83
#  OsteocephalusOophagus       0.91      0.57      0.70        35
#      Rhinellagranulosa       0.84      0.91      0.87        23
#            ScinaxRuber       0.93      0.97      0.95        39
#
#               accuracy                           0.96      2159
#              macro avg       0.92      0.89      0.90      2159
#           weighted avg       0.95      0.96      0.95      2159

# %%
multiLabelEva("Support Vector Classifier with L1-penalty", X_test_STD, MFCC_test.iloc[:, -4:-1], L1_penalized_std_attri)
# Out:
# Multilabel evaluation of Support Vector Classifier with L1-penalty
#    Hamming Loss  Exact Match Ratio
# 0        0.9231             0.0513
# [0.9231, 0.0513]

# %% [markdown]
# #### using SMOTE or any other method for imbalance

# %%
def SMOTEParameterSearch(classifier, settings, X_train, Y_train, X_test, Y_test, label):
    naive_model = Pipeline([
        ('sampling', SMOTE()),
        ('classification', classifier)
    ])
    selected_model = ParameterSearch(naive_model, settings, X_train, Y_train, X_test, Y_test, label)
    print(f"Class: {label} (L1-penalized and SMOTE with Standardization)")
    return selected_model

# %%
tuned_params = {'classification__C': np.logspace(0, 3, 5)}
SMOTE_SVC_classifiers = {}
# splitter = StratifiedKFold(n_splits=10, random_state=1234, shuffle=True)
# kwargs = {
#     'param_grid': tuned_params,
#     'cv': splitter,
#     'scoring': 'f1_weighted',
#     'verbose': 1
# }
labels = ['Family', 'Genus', 'Species']

# %%
for label in labels:
    SMOTE_SVC_classifiers[label] = SMOTEParameterSearch(
        LinearSVC(penalty='l1', dual=False),
        tuned_params,
        X_train_STD,
        train_data[f'train_{label.lower()}'],
        X_test_STD,
        test_data[f'test_{label.lower()}'],
        label
    )
# Out:
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# Class: Family (Gaussian SVC without Standardization)
# Grid Search Results:
#
# Mean Score: 0.921 (±0.022) for Parameters: {'classification__C': 1.0}
# Mean Score: 0.922 (±0.023) for Parameters: {'classification__C': 5.623413251903491}
# Mean Score: 0.922 (±0.024) for Parameters: {'classification__C': 31.622776601683793}
# Mean Score: 0.921 (±0.024) for Parameters: {'classification__C': 177.82794100389228}
# Mean Score: 0.922 (±0.024) for Parameters: {'classification__C': 1000.0}
#
# The best parameter setting is:
# {'classification__C': 1000.0}
#
#                  precision    recall  f1-score   support
#
#       Bufonidae       0.36      0.91      0.52        23
#   Dendrobatidae       0.77      0.99      0.86       161
#         Hylidae       0.94      0.89      0.91       666
# Leptodactylidae       0.98      0.94      0.96      1309
#
#        accuracy                           0.93      2159
#       macro avg       0.76      0.93      0.81      2159
#    weighted avg       0.94      0.93      0.93      2159
#
# Class: Family (L1-penalized and SMOTE with Standardization)
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# Class: Genus (Gaussian SVC without Standardization)
# Grid Search Results:
#
# Mean Score: 0.918 (±0.023) for Parameters: {'classification__C': 1.0}
# Mean Score: 0.915 (±0.025) for Parameters: {'classification__C': 5.623413251903491}
# Mean Score: 0.917 (±0.022) for Parameters: {'classification__C': 31.622776601683793}
# Mean Score: 0.917 (±0.023) for Parameters: {'classification__C': 177.82794100389228}
# Mean Score: 0.916 (±0.023) for Parameters: {'classification__C': 1000.0}
#
# The best parameter setting is:
# {'classification__C': 1.0}
#
#                precision    recall  f1-score   support
#
#     Adenomera       0.99      0.90      0.94      1226
#      Ameerega       0.84      0.93      0.88       161
# Dendropsophus       0.59      0.92      0.72        78
#     Hypsiboas       0.96      0.92      0.94       514
# Leptodactylus       0.92      0.93      0.92        83
# Osteocephalus       0.45      0.86      0.59        35
#      Rhinella       0.43      0.91      0.58        23
#        Scinax       0.81      1.00      0.90        39
#
#      accuracy                           0.91      2159
#     macro avg       0.75      0.92      0.81      2159
#  weighted avg       0.94      0.91      0.92      2159
#
# Class: Genus (L1-penalized and SMOTE with Standardization)
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# Class: Species (Gaussian SVC without Standardization)
# Grid Search Results:
#
# Mean Score: 0.958 (±0.017) for Parameters: {'classification__C': 1.0}
# Mean Score: 0.957 (±0.013) for Parameters: {'classification__C': 5.623413251903491}
# Mean Score: 0.958 (±0.015) for Parameters: {'classification__C': 31.622776601683793}
# Mean Score: 0.957 (±0.013) for Parameters: {'classification__C': 177.82794100389228}
# Mean Score: 0.958 (±0.014) for Parameters: {'classification__C': 1000.0}
#
# The best parameter setting is:
# {'classification__C': 1.0}
#
#                         precision    recall  f1-score   support
#
#         AdenomeraAndre       0.94      0.89      0.92       209
# AdenomeraHylaedactylus       1.00      0.99      0.99      1017
#     Ameeregatrivittata       0.94      0.89      0.91       161
#             HylaMinuta       0.74      0.92      0.82        78
#   HypsiboasCinerascens       0.92      0.95      0.94       155
#      HypsiboasCordobae       0.98      0.94      0.96       359
#    LeptodactylusFuscus       0.95      0.92      0.93        83
#  OsteocephalusOophagus       0.79      0.86      0.82        35
#      Rhinellagranulosa       0.67      0.96      0.79        23
#            ScinaxRuber       0.90      0.97      0.94        39
#
#               accuracy                           0.96      2159
#              macro avg       0.88      0.93      0.90      2159
#           weighted avg       0.96      0.96      0.96      2159
#
# Class: Species (L1-penalized and SMOTE with Standardization)

# %%
multiLabelEva("SMOTE with L1-penalized SVMs and Standardized Attributes", X_test_STD, MFCC_test.iloc[:, -4:-1], SMOTE_SVC_classifiers)
# Out:
# Multilabel evaluation of SMOTE with L1-penalized SVMs and Standardized Attributes
#    Hamming Loss  Exact Match Ratio
# 0        0.8685             0.0684
# [0.8685, 0.0684]

# %%
Gaussian_SVC_Raw_Attributes = pd.DataFrame({
    "Method": ["Gaussian_SVC_Raw_Attributes"],
    "Hamming Loss": [0.9856],
    "Exact Match Ratio": [0.01]
})

Gaussian_SVC_Standardized_Attributes = pd.DataFrame({
    "Method": ["Gaussian_SVC_Standardized_Attributes"],
    "Hamming Loss": [0.9819],
    "Exact Match Ratio": [0.0117]
})

L1_Penalized = pd.DataFrame({
    "Method": ["L1_Penalized"],
    "Hamming Loss": [0.9231],
    "Exact Match Ratio": [0.0513]
})

SMOTE = pd.DataFrame({
    "Method": ["SMOTE"],
    "Hamming Loss": [0.8685],
    "Exact Match Ratio": [0.0684]
})

# %%
# Concatenating the DataFrames
combined_df = pd.concat([Gaussian_SVC_Raw_Attributes, Gaussian_SVC_Standardized_Attributes, L1_Penalized, SMOTE])

# Set 'Method' as the index (optional)
combined_df.set_index('Method', inplace=True)
combined_df
# Out:
#                                       Hamming Loss  Exact Match Ratio
# Method
# Gaussian_SVC_Raw_Attributes                 0.9856             0.0100
# Gaussian_SVC_Standardized_Attributes        0.9819             0.0117
# L1_Penalized                                0.9231             0.0513
# SMOTE                                       0.8685             0.0684

# %% [markdown]
# ## K-Means Clustering on a Multi-Class and Multi-Label Data Set

# %% [markdown]
# - Use k-means clustering
# - Determine which family is the majority
# - Calculate the average Hamming distance, Hamming score, and Hamming loss

# %%
# get optimal k
def OptimalK(X, num_clusters, rand_state):
    # method used is Silhouettes
    silhouette_scores = []
    for n in range(2, num_clusters+1):
        kmeans = KMeans(n_clusters=n, random_state=rand_state)
        cluster_labels = kmeans.fit_predict(X)
        silhouette_avg = silhouette_score(X, cluster_labels)
        silhouette_scores.append(silhouette_avg)
    optimal_K = silhouette_scores.index(max(silhouette_scores)) + 2  # Adding 2 as range starts from 2
    print(f"The optimal K is: {optimal_K}")
    return optimal_K

# majority labels of a cluster
def MajorityLabels(optimal_K, cluster_labels, Y):
    cluster_major = pd.DataFrame(columns=Y.columns)
    for cluster in range(optimal_K):
        index, = np.where(cluster_labels == cluster)
        cluster_samples = Y.iloc[index, :]
        row = []
        for label in Y.columns:
            cur_major = cluster_samples.loc[:, label].value_counts().index[0]
            row.append(cur_major)
        cluster_major.loc[cluster] = row
    return cluster_major

# calculate hamming distance/loss
# def Hamming_Distance_Loss(cluster_major, cluster_labels, Y):
#     cluster_major = cluster_major.loc[cluster_labels]  # Align the labels
#     hamming_dist = (cluster_major != Y).sum().sum() / (Y.shape[0] * Y.shape[1])
#     hamming_loss = hamming_dist / Y.shape[1]
#     return hamming_dist, hamming_loss

def Hamming_Distance_Loss(cluster_major, cluster_labels, Y):
    cluster_major = cluster_major.loc[cluster_labels]  # Align the labels
    Y = Y.iloc[cluster_labels]  # Align Y with the cluster labels
    hamming_dist = (cluster_major != Y).sum().sum() / (Y.shape[0] * Y.shape[1])
    hamming_loss = hamming_dist / Y.shape[1]
    return hamming_dist, hamming_loss

def MonteCarlo(times, X, Y):
    hamming_dist = []
    hamming_loss = []
    for i in range(times):
        optimal_K = OptimalK(X, num_clusters=50, rand_state=i)
        clusterer = KMeans(n_clusters=optimal_K, random_state=i)
        cluster_labels = clusterer.fit_predict(X)
        majority_families = MajorityLabels(optimal_K, cluster_labels, Y)
        cur_dist, cur_loss = Hamming_Distance_Loss(majority_families, cluster_labels, Y)
        hamming_dist.append(cur_dist)
        hamming_loss.append(cur_loss)
        print(f"Iteration {i + 1} | Major Family: {majority_families}, Hamming Distance: {round(cur_dist, 4)}, Hamming Loss: {round(cur_loss, 4)}")
    return majority_families, hamming_dist, hamming_loss

# %%
iterations = 50
majority_families, hamming_dist, hamming_loss = MonteCarlo(iterations, MFCC_df.iloc[:, :-4], MFCC_df.iloc[:, -4:-1])
# Out:
# The optimal K is: 4
# Iteration 1 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 2 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas       HypsiboasCordobae
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 3 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1  Leptodactylidae  Adenomera          AdenomeraAndre
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.5712, Hamming Loss: 0.1904
# The optimal K is: 4
# Iteration 4 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1    Dendrobatidae   Ameerega      Ameeregatrivittata
# 2          Hylidae  Hypsiboas    HypsiboasCinerascens
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 5 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2          Hylidae  Hypsiboas    HypsiboasCinerascens
# 3    Dendrobatidae   Ameerega      Ameeregatrivittata, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 6 | Major Family:             Family      Genus                 Species
# 0    Dendrobatidae   Ameerega      Ameeregatrivittata
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas    HypsiboasCinerascens
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 7 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas    HypsiboasCinerascens
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3    Dendrobatidae   Ameerega      Ameeregatrivittata, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 8 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas    HypsiboasCinerascens
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 9 | Major Family:             Family      Genus                 Species
# 0    Dendrobatidae   Ameerega      Ameeregatrivittata
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas    HypsiboasCinerascens
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 10 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1    Dendrobatidae   Ameerega      Ameeregatrivittata
# 2          Hylidae  Hypsiboas    HypsiboasCinerascens
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 11 | Major Family:             Family      Genus                 Species
# 0    Dendrobatidae   Ameerega      Ameeregatrivittata
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 12 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas    HypsiboasCinerascens
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 3    Dendrobatidae   Ameerega      Ameeregatrivittata, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 13 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 14 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas       HypsiboasCordobae
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 15 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas       HypsiboasCordobae
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 16 | Major Family:             Family      Genus                 Species
# 0    Dendrobatidae   Ameerega      Ameeregatrivittata
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 17 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas    HypsiboasCinerascens
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3    Dendrobatidae   Ameerega      Ameeregatrivittata, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 18 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas    HypsiboasCinerascens
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 19 | Major Family:             Family      Genus                 Species
# 0    Dendrobatidae   Ameerega      Ameeregatrivittata
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 20 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1    Dendrobatidae   Ameerega      Ameeregatrivittata
# 2          Hylidae  Hypsiboas    HypsiboasCinerascens
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 21 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 22 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera          AdenomeraAndre
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.5709, Hamming Loss: 0.1903
# The optimal K is: 4
# Iteration 23 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2  Leptodactylidae  Adenomera          AdenomeraAndre
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.5669, Hamming Loss: 0.189
# The optimal K is: 4
# Iteration 24 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 25 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 26 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas    HypsiboasCinerascens
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3    Dendrobatidae   Ameerega      Ameeregatrivittata, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 27 | Major Family:             Family      Genus                 Species
# 0    Dendrobatidae   Ameerega      Ameeregatrivittata
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 28 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas    HypsiboasCinerascens
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3    Dendrobatidae   Ameerega      Ameeregatrivittata, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 29 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 30 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas       HypsiboasCordobae
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 31 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas    HypsiboasCinerascens
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 32 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera          AdenomeraAndre
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.5709, Hamming Loss: 0.1903
# The optimal K is: 4
# Iteration 33 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2          Hylidae  Hypsiboas    HypsiboasCinerascens
# 3    Dendrobatidae   Ameerega      Ameeregatrivittata, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 34 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas    HypsiboasCinerascens
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3    Dendrobatidae   Ameerega      Ameeregatrivittata, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 35 | Major Family:             Family      Genus                 Species
# 0    Dendrobatidae   Ameerega      Ameeregatrivittata
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas    HypsiboasCinerascens
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 36 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas       HypsiboasCordobae
# 1    Dendrobatidae   Ameerega      Ameeregatrivittata
# 2  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 37 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas    HypsiboasCinerascens
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3    Dendrobatidae   Ameerega      Ameeregatrivittata, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 38 | Major Family:             Family      Genus                 Species
# 0    Dendrobatidae   Ameerega      Ameeregatrivittata
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 39 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas    HypsiboasCinerascens
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 40 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas    HypsiboasCinerascens
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3    Dendrobatidae   Ameerega      Ameeregatrivittata, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 41 | Major Family:             Family      Genus                 Species
# 0    Dendrobatidae   Ameerega      Ameeregatrivittata
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 42 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas    HypsiboasCinerascens
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 43 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas    HypsiboasCinerascens
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 44 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas    HypsiboasCinerascens
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 45 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 46 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas    HypsiboasCinerascens
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas       HypsiboasCordobae, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 47 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas    HypsiboasCinerascens
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3    Dendrobatidae   Ameerega      Ameeregatrivittata, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 48 | Major Family:             Family      Genus                 Species
# 0    Dendrobatidae   Ameerega      Ameeregatrivittata
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 49 | Major Family:             Family      Genus                 Species
# 0  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 1          Hylidae  Hypsiboas       HypsiboasCordobae
# 2    Dendrobatidae   Ameerega      Ameeregatrivittata
# 3          Hylidae  Hypsiboas    HypsiboasCinerascens, Hamming Distance: 0.6694, Hamming Loss: 0.2231
# The optimal K is: 4
# Iteration 50 | Major Family:             Family      Genus                 Species
# 0          Hylidae  Hypsiboas    HypsiboasCinerascens
# 1  Leptodactylidae  Adenomera  AdenomeraHylaedactylus
# 2          Hylidae  Hypsiboas       HypsiboasCordobae
# 3    Dendrobatidae   Ameerega      Ameeregatrivittata, Hamming Distance: 0.6694, Hamming Loss: 0.2231

# %%
def summarize(hamming_distance, hamming_loss):
    summary = {
        "Avg Hamming Distance": round(np.mean(hamming_distance), 4),
        "Std of Hamming Distance": round(np.std(hamming_distance), 4),
        "Avg Hamming Loss": round(np.mean(hamming_loss), 4),
        "Std of Hamming Loss": round(np.std(hamming_loss), 4),
        "Avg Hamming Score": round(1 - np.mean(hamming_loss), 4),
        "Std of Hamming Score": round(np.std(hamming_loss), 4)
    }
    
    return pd.DataFrame(summary, index=[0])

# %%
hamming_summary = summarize(hamming_dist, hamming_loss)
hamming_summary
# Out:
#    Avg Hamming Distance  Std of Hamming Distance  Avg Hamming Loss  \
# 0                0.6614                    0.027            0.2205
#
#    Std of Hamming Loss  Avg Hamming Score  Std of Hamming Score
# 0                0.009             0.7795                 0.009
